# %% [markdown]
# ### Movie budgets

# %% [markdown]
# Using this DataFrame we are going to try to predict if a film's budget is related to the love of the people for the movie. For this purpose we are going to use two different DataFrames.

# %%
import numpy as np
import os
import re
import pandas as pd
import seaborn as sns
from datetime import datetime
import squarify
import matplotlib.pyplot as plt

# %% [markdown]
# ***
#
# ### df_budgets

# %%
df_budgets = pd.read_csv("top-500-movies.csv", index_col = 0)

# %%
df_budgets.head(2)
# Out:
#      release_date                                        title  \
# rank
# 1      2019-04-23                            Avengers: Endgame
# 2      2011-05-20  Pirates of the Caribbean: On Stranger Tides
#
#                                                     url  production_cost  \
# rank
# 1            /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# 2     /movie/Pirates-of-the-Caribbean-On-Stranger-Ti...        379000000
#
#       domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# rank
# 1          858373000       2797800564      357115007.0  PG-13     Action
# 2          241071802       1045713802       90151958.0  PG-13  Adventure
#
#       theaters  runtime    year
# rank
# 1       4662.0    181.0  2019.0
# 2       4164.0    136.0  2011.0

# %% [markdown]
# First, we drop the "url" column:

# %%
df_budgets.drop("url", inplace = True, axis = 1)

# %%
df_budgets.dtypes
# Out:
# release_date        object
# title               object
# production_cost      int64
# domestic_gross       int64
# worldwide_gross      int64
# opening_weekend    float64
# mpaa                object
# genre               object
# theaters           float64
# runtime            float64
# year               float64
# dtype: object

# %%
df_budgets.isnull().sum()
# Out:
# release_date        1
# title               0
# production_cost     0
# domestic_gross      0
# worldwide_gross     0
# opening_weekend    21
# mpaa                8
# genre               5
# theaters           21
# runtime            13
# year                1
# dtype: int64

# %% [markdown]
# We find there are many null values. We will fill them manually.

# %%
df_budgets["release_date"] = df_budgets["release_date"].replace(np.nan, 2022)

# %%
df_budgets[df_budgets["theaters"].isna()]
# Out:
#      release_date                                             title  \
# rank
# 9      2023-07-11       Mission: Impossible Dead Reckoning Part One
# 84     2020-09-04                                             Mulan
# 85     2021-07-02                                  The Tomorrow War
# 86     2022-07-13                                      The Gray Man
# 110    2005-12-09  The Chronicles of Narnia: The Lion, the Witch a…
# 141    2022-03-10                                       Turning Red
# 180    2019-11-01                                      The Irishman
# 182    2010-12-10  The Chronicles of Narnia: The Voyage of the Daw…
# 235    2021-11-04                                        Red Notice
# 236    2019-12-13                                     6 Underground
# 247    2003-07-09  Pirates of the Caribbean: The Curse of the Blac…
# 261          2022                                    Desert Warrior
# 344    2015-08-05                                The Fantastic Four
# 348    2018-11-09                                       Outlaw King
# 349    2022-12-02                                      Emancipation
# 351    2021-01-25                             Tang Ren Jie Tan An 3
# 361    2019-03-06                                   Triple Frontier
# 362    2008-07-04                       Astérix aux Jeux Olympiques
# 465    2020-12-09                                  The Midnight Sky
# 466    2020-06-12                                      Artemis Fowl
# 500    2023-03-09                                                65
#
#       production_cost  domestic_gross  worldwide_gross  opening_weekend  \
# rank
# 9           290000000               0                0              NaN
# 84          200000000               0         69965374              NaN
# 85          200000000               0         19220000              NaN
# 86          200000000               0           451178              NaN
# 110         180000000       291710957        720539572              NaN
# 141         175000000               0         10965045              NaN
# 180         159000000               0           910234              NaN
# 182         155000000       104386950        418186950              NaN
# 235         150000000               0           173638              NaN
# 236         150000000               0                0              NaN
# 247         140000000       305410819        654310819              NaN
# 261         140000000               0                0              NaN
# 344         120000000        56117548        167849187              NaN
# 348         120000000               0                0              NaN
# 349         120000000               0                0              NaN
# 351         117000000               0        699084069              NaN
# 361         115000000               0                0              NaN
# 362         113500000          999811        132999811              NaN
# 465         100000000               0            75615              NaN
# 466         100000000               0                0              NaN
# 500          91000000               0                0              NaN
#
#          mpaa              genre  theaters  runtime    year
# rank
# 9         NaN             Action       NaN      NaN  2023.0
# 84      PG-13          Adventure       NaN    115.0  2020.0
# 85      PG-13             Action       NaN    140.0  2021.0
# 86      PG-13  Thriller/Suspense       NaN    129.0  2022.0
# 110       NaN                NaN       NaN      NaN  2005.0
# 141        PG          Adventure       NaN    100.0  2022.0
# 180         R              Drama       NaN    210.0  2019.0
# 182       NaN                NaN       NaN      NaN  2010.0
# 235     PG-13             Action       NaN    115.0  2021.0
# 236         R             Action       NaN    128.0  2019.0
# 247       NaN                NaN       NaN      NaN  2003.0
# 261       NaN                NaN       NaN      NaN     NaN
# 344       NaN                NaN       NaN      NaN  2015.0
# 348         R             Action       NaN    117.0  2018.0
# 349       NaN  Thriller/Suspense       NaN    132.0  2022.0
# 351         R             Action       NaN    136.0  2021.0
# 361         R             Action       NaN    125.0  2019.0
# 362   Unrated          Adventure       NaN      NaN  2008.0
# 465     PG-13          Adventure       NaN    118.0  2020.0
# 466        PG          Adventure       NaN    115.0  2020.0
# 500       NaN  Thriller/Suspense       NaN      NaN  2023.0

# %% [markdown]
# ***
#
# ### df_ratings

# %%
df_ratings = pd.read_csv("movie_ratings.csv")

# %%
df_ratings.head()
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.6          6.00
# 3  Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0          8.00
# 4  Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9          5.33
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
# 2          5.0            9
# 3          6.0           18
# 4          7.0           15
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
# 1  Luigi Perelli, the director of the "Piovra", o...      0       2       0
# 2  "Ecological" story with a happy ending, not wi...      1       2       1
# 3  A cast of will be famous for Levinson's direct...      2       2       0
# 4  Taken from the play by Armando Curcio that the...      3       1       1
#
#    tension  erotism
# 0        0        0
# 1        2        0
# 2        0        0
# 3        1        2
# 4        0        0

# %% [markdown]
# We drop all the columns we find no use for:

# %%
df_ratings.drop("actors", inplace = True, axis = 1)

# %%
df_ratings.drop("humor", inplace = True, axis = 1)

# %%
df_ratings.drop("rhythm", inplace = True, axis = 1)

# %%
df_ratings.drop("effort", inplace = True, axis = 1)

# %%
df_ratings.drop("tension", inplace = True, axis = 1)

# %%
df_ratings.drop("erotism", inplace = True, axis = 1)

# %%
df_ratings.drop("total_votes", inplace = True, axis = 1)

# %%
df_ratings.drop("notes", inplace = True, axis = 1)

# %%
df_ratings[df_ratings["title"] == "Avengers: Endgame"]
# Out:
#        filmtv_id              title  year       genre  duration  \
# 36532     166273  Avengers: Endgame  2019  Super-hero       181
#
#              country                 directors  avg_vote  critics_vote  \
# 36532  United States  Anthony Russo, Joe Russo       6.2          6.33
#
#        public_vote                                        description
# 36532          6.0  Half of the living beings in the universe were...

# %%
df_ratings.head(2)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
#
#    duration        country                             directors  avg_vote  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez       7.7
# 1        98          Italy                         Luigi Perelli       6.5
#
#    critics_vote  public_vote  \
# 0           8.0          7.0
# 1           6.0          7.0
#
#                                          description
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...

# %%
df_budgets.head()
# Out:
#      release_date                                        title  \
# rank
# 1      2019-04-23                            Avengers: Endgame
# 2      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3      2015-04-22                      Avengers: Age of Ultron
# 4      2015-12-16         Star Wars Ep. VII: The Force Awakens
# 5      2018-04-25                       Avengers: Infinity War
#
#       production_cost  domestic_gross  worldwide_gross  opening_weekend  \
# rank
# 1           400000000       858373000       2797800564      357115007.0
# 2           379000000       241071802       1045713802       90151958.0
# 3           365000000       459005868       1395316979      191271109.0
# 4           306000000       936662225       2064615817      247966675.0
# 5           300000000       678815482       2048359754      257698183.0
#
#        mpaa      genre  theaters  runtime    year
# rank
# 1     PG-13     Action    4662.0    181.0  2019.0
# 2     PG-13  Adventure    4164.0    136.0  2011.0
# 3     PG-13     Action    4276.0    141.0  2015.0
# 4     PG-13  Adventure    4134.0    136.0  2015.0
# 5     PG-13     Action    4474.0    156.0  2018.0

# %%
df_budgets.isnull().sum()
# Out:
# release_date        0
# title               0
# production_cost     0
# domestic_gross      0
# worldwide_gross     0
# opening_weekend    21
# mpaa                8
# genre               5
# theaters           21
# runtime            13
# year                1
# dtype: int64

# %%
df_ratings.isnull().sum()
# Out:
# filmtv_id          0
# title              0
# year               0
# genre             95
# duration           0
# country           11
# directors         33
# avg_vote           0
# critics_vote    4600
# public_vote      474
# description     1455
# dtype: int64

# %%
df_ratings.shape[0]
# Out:
# 40303

# %%
df_budgets.shape[0]
# Out:
# 500

# %% [markdown]
# ***
#
# ### We concat both columns.

# %%
df_total_merge = df_budgets.merge(df_ratings)

# %%
df_total_merge.shape
# Out:
# (97, 19)

# %%
df_total_merge.head()
# Out:
#   release_date                                title  production_cost  \
# 0   2015-10-06                              Spectre        300000000
# 1   2013-12-12  The Hobbit: The Desolation of Smaug        250000000
# 2   2017-04-07              The Fate of the Furious        250000000
# 3   2012-07-19                The Dark Knight Rises        230000000
# 4   2012-04-11                           Battleship        220000000
#
#    domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 0       200074175        879500760       70403148.0  PG-13     Action
# 1       258241522        959358436       73645197.0  PG-13  Adventure
# 2       225764765       1236703796       98786705.0  PG-13     Action
# 3       448139099       1082228107      160887295.0  PG-13     Action
# 4        65233400        313477717       25534825.0  PG-13     Action
#
#    theaters  runtime    year  filmtv_id  duration  \
# 0    3929.0    148.0  2015.0      73835       148
# 1    3928.0    201.0  2013.0      44164       170
# 2    4329.0    136.0  2017.0     124716       136
# 3    4404.0    164.0  2012.0      45819       165
# 4    3702.0    130.0  2012.0      46201       131
#
#                                              country          directors  \
# 0                       United States, Great Britain         Sam Mendes
# 1                         United States, New Zealand      Peter Jackson
# 2  United States, Japan, France, Canada, American...       F. Gary Gray
# 3                       United States, Great Britain  Christopher Nolan
# 4                                      United States         Peter Berg
#
#    avg_vote  critics_vote  public_vote  \
# 0       6.1          6.38          6.0
# 1       6.4          6.30          7.0
# 2       4.8          4.71          5.0
# 3       6.9          7.08          7.0
# 4       4.7          4.64          5.0
#
#                                          description
# 0  A cryptic message from his past sends James Bo...
# 1  After managing to escape the misty mountains, ...
# 2  Dom and Letty are on their honeymoon while Bri...
# 3  It's been a few years since Bruce Wayne (Chris...
# 4  To save the planet from the attack of a superi...

# %%
df_total_concat = pd.concat([df_budgets, df_ratings], axis = 1)

# %% [markdown]
# **FIX: Concat index**

# %%
df_budgets.head()
# Out:
#      release_date                                        title  \
# rank
# 1      2019-04-23                            Avengers: Endgame
# 2      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3      2015-04-22                      Avengers: Age of Ultron
# 4      2015-12-16         Star Wars Ep. VII: The Force Awakens
# 5      2018-04-25                       Avengers: Infinity War
#
#       production_cost  domestic_gross  worldwide_gross  opening_weekend  \
# rank
# 1           400000000       858373000       2797800564      357115007.0
# 2           379000000       241071802       1045713802       90151958.0
# 3           365000000       459005868       1395316979      191271109.0
# 4           306000000       936662225       2064615817      247966675.0
# 5           300000000       678815482       2048359754      257698183.0
#
#        mpaa      genre  theaters  runtime    year
# rank
# 1     PG-13     Action    4662.0    181.0  2019.0
# 2     PG-13  Adventure    4164.0    136.0  2011.0
# 3     PG-13     Action    4276.0    141.0  2015.0
# 4     PG-13  Adventure    4134.0    136.0  2015.0
# 5     PG-13     Action    4474.0    156.0  2018.0

# %%
df_ratings = df_ratings.set_index('title')

# %%
df_ratings.head()
# Out:
#                                              filmtv_id  year      genre  \
# title
# Bugs Bunny's Third Movie: 1001 Rabbit Tales          2  1982  Animation
# 18 anni tra una settimana                            3  1991      Drama
# Ride a Wild Pony                                    17  1976   Romantic
# Diner                                               18  1982     Comedy
# A che servono questi quattrini?                     20  1942     Comedy
#
#                                              duration        country  \
# title
# Bugs Bunny's Third Movie: 1001 Rabbit Tales        76  United States
# 18 anni tra una settimana                          98          Italy
# Ride a Wild Pony                                   91  United States
# Diner                                              95  United States
# A che servono questi quattrini?                    85          Italy
#
#                                                                         directors  \
# title
# Bugs Bunny's Third Movie: 1001 Rabbit Tales  David Detiege, Art Davis, Bill Perez
# 18 anni tra una settimana                                           Luigi Perelli
# Ride a Wild Pony                                                      Don Chaffey
# Diner                                                              Barry Levinson
# A che servono questi quattrini?                                    Esodo Pratelli
#
#                                              avg_vote  critics_vote  \
# title
# Bugs Bunny's Third Movie: 1001 Rabbit Tales       7.7          8.00
# 18 anni tra una settimana                         6.5          6.00
# Ride a Wild Pony                                  5.6          6.00
# Diner                                             7.0          8.00
# A che servono questi quattrini?                   5.9          5.33
#
#                                              public_vote  \
# title
# Bugs Bunny's Third Movie: 1001 Rabbit Tales          7.0
# 18 anni tra una settimana                            7.0
# Ride a Wild Pony                                     5.0
# Diner                                                6.0
# A che servono questi quattrini?                      7.0
#
#                                                                                    description
# title
# Bugs Bunny's Third Movie: 1001 Rabbit Tales  With two protruding front teeth, a slightly sl...
# 18 anni tra una settimana                    Samantha, not yet eighteen, leaves the comfort...
# Ride a Wild Pony                             In the Australia of the pioneers, a boy and a ...
# Diner                                        Five boys from Baltimore have a habit of meeti...
# A che servono questi quattrini?              With a stratagem, the penniless and somewhat p...

# %%
df_total2 = pd.concat([df_budgets, df_ratings], axis = 1, join='inner')
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /var/folders/c9/6zwnylqn0v3b4prwfdpt2ndc0000gn/T/ipykernel_996/352278703.py in <module>
# ----> 1 df_total2 = pd.concat([df_budgets, df_ratings], axis = 1, join='inner')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     526                     obj_labels = obj.axes[1 - ax]
#     527                     if not new_labels.equals(obj_labels):
# --> 528                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     529
#     530                 mgrs_indexers.append((obj._mgr, indexers))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3440
#    3441         if not self._index_as_unique:
# -> 3442             raise InvalidIndexError(self._requires_unique_msg)
#    3443
#    3444         if not self._should_compare(target) and not is_interval_dtype(self.dtype):
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
df_total_concat.head()
# Out:
#   release_date                                        title  production_cost  \
# 0          NaN                                          NaN              NaN
# 1   2019-04-23                            Avengers: Endgame      400000000.0
# 2   2011-05-20  Pirates of the Caribbean: On Stranger Tides      379000000.0
# 3   2015-04-22                      Avengers: Age of Ultron      365000000.0
# 4   2015-12-16         Star Wars Ep. VII: The Force Awakens      306000000.0
#
#    domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 0             NaN              NaN              NaN    NaN        NaN
# 1     858373000.0     2.797801e+09      357115007.0  PG-13     Action
# 2     241071802.0     1.045714e+09       90151958.0  PG-13  Adventure
# 3     459005868.0     1.395317e+09      191271109.0  PG-13     Action
# 4     936662225.0     2.064616e+09      247966675.0  PG-13  Adventure
#
#    theaters  runtime  ...                                        title  year  \
# 0       NaN      NaN  ...  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982
# 1    4662.0    181.0  ...                    18 anni tra una settimana  1991
# 2    4164.0    136.0  ...                             Ride a Wild Pony  1976
# 3    4276.0    141.0  ...                                        Diner  1982
# 4    4134.0    136.0  ...              A che servono questi quattrini?  1942
#
#        genre  duration        country                             directors  \
# 0  Animation        76  United States  David Detiege, Art Davis, Bill Perez
# 1      Drama        98          Italy                         Luigi Perelli
# 2   Romantic        91  United States                           Don Chaffey
# 3     Comedy        95  United States                        Barry Levinson
# 4     Comedy        85          Italy                        Esodo Pratelli
#
#   avg_vote critics_vote  public_vote  \
# 0      7.7         8.00          7.0
# 1      6.5         6.00          7.0
# 2      5.6         6.00          5.0
# 3      7.0         8.00          6.0
# 4      5.9         5.33          7.0
#
#                                          description
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
#
# [5 rows x 22 columns]

# %%
df_total_concat.shape
# Out:
# (40303, 22)

# %%
df_total_concat.isnull().sum()
# Out:
# release_date       39803
# title              39803
# production_cost    39803
# domestic_gross     39803
# worldwide_gross    39803
# opening_weekend    39824
# mpaa               39811
# genre              39808
# theaters           39824
# runtime            39816
# year               39804
# filmtv_id              0
# title                  0
# year                   0
# genre                 95
# duration               0
# country               11
# directors             33
# avg_vote               0
# critics_vote        4600
# public_vote          474
# description         1455
# dtype: int64

# %%
df_final = df_total_concat.dropna()

# %%
df_final.isnull().sum()
# Out:
# release_date       0
# title              0
# production_cost    0
# domestic_gross     0
# worldwide_gross    0
# opening_weekend    0
# mpaa               0
# genre              0
# theaters           0
# runtime            0
# year               0
# filmtv_id          0
# title              0
# year               0
# genre              0
# duration           0
# country            0
# directors          0
# avg_vote           0
# critics_vote       0
# public_vote        0
# description        0
# dtype: int64

# %%
df_final.shape
# Out:
# (474, 22)

# %%
df_final.tail()
# Out:
#     release_date                            title  production_cost  \
# 494   2008-02-14        The Spiderwick Chronicles       92500000.0
# 495   2004-10-22                  The Incredibles       92000000.0
# 496   2013-02-06           A Good Day to Die Hard       92000000.0
# 497   2004-04-09                        The Alamo       92000000.0
# 499   2013-12-19  The Secret Life of Walter Mitty       91000000.0
#
#      domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 494      71195053.0      162839667.0       19004058.0     PG  Adventure
# 495     261441092.0      631441092.0       70467623.0     PG  Adventure
# 496      67349198.0      304249198.0       24834845.0      R     Action
# 497      22406362.0       23911362.0        9124701.0  PG-13    Western
# 499      58236838.0      187861183.0       12765508.0     PG  Adventure
#
#      theaters  runtime  ...                     title  year   genre  duration  \
# 494    3847.0     96.0  ...           Kiss Me, Stupid  1964  Comedy       123
# 495    3933.0    115.0  ...                  Il bacio  1974   Drama       105
# 496    3555.0     98.0  ...             Killer's Kiss  1955    Noir        67
# 497    2609.0    137.0  ...  Kiss of the Spider Woman  1985   Drama       119
# 499    2922.0    114.0  ...                Cat People  1982  Horror       118
#
#                    country         directors avg_vote critics_vote  \
# 494          United States      Billy Wilder      8.3         8.43
# 495                  Italy  Mario Lanfranchi      3.8         4.00
# 496          United States   Stanley Kubrick      7.1         7.10
# 497  United States, Brazil    Hector Babenco      7.7         7.75
# 499          United States     Paul Schrader      6.7         6.79
#
#      public_vote                                        description
# 494          8.0  Orville is a piano teacher from a provincial t...
# 495          4.0  A coveted noble title (and relative patrimony)...
# 496          7.0  Dave Gordon, a failed boxer, meets Gloria who ...
# 497          8.0  Two men are being held in the same cell in a S...
# 499          7.0  Irena Gallier (Kinski) is already grown up, bu...
#
# [5 rows x 22 columns]

# %%
df_final[df_final.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [release_date, title, production_cost, domestic_gross, worldwide_gross, opening_weekend, mpaa, genre, theaters, runtime, year, filmtv_id, title, year, genre, duration, country, directors, avg_vote, critics_vote, public_vote, description]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_final.index.is_unique
# Out:
# True

# %%
df_final.loc[~df_final.index.duplicated(), :]
# Out:
#     release_date                                        title  \
# 1     2019-04-23                            Avengers: Endgame
# 2     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3     2015-04-22                      Avengers: Age of Ultron
# 4     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 5     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 494   2008-02-14                    The Spiderwick Chronicles
# 495   2004-10-22                              The Incredibles
# 496   2013-02-06                       A Good Day to Die Hard
# 497   2004-04-09                                    The Alamo
# 499   2013-12-19              The Secret Life of Walter Mitty
#
#      production_cost  domestic_gross  worldwide_gross  opening_weekend   mpaa  \
# 1        400000000.0     858373000.0     2.797801e+09      357115007.0  PG-13
# 2        379000000.0     241071802.0     1.045714e+09       90151958.0  PG-13
# 3        365000000.0     459005868.0     1.395317e+09      191271109.0  PG-13
# 4        306000000.0     936662225.0     2.064616e+09      247966675.0  PG-13
# 5        300000000.0     678815482.0     2.048360e+09      257698183.0  PG-13
# ..               ...             ...              ...              ...    ...
# 494       92500000.0      71195053.0     1.628397e+08       19004058.0     PG
# 495       92000000.0     261441092.0     6.314411e+08       70467623.0     PG
# 496       92000000.0      67349198.0     3.042492e+08       24834845.0      R
# 497       92000000.0      22406362.0     2.391136e+07        9124701.0  PG-13
# 499       91000000.0      58236838.0     1.878612e+08       12765508.0     PG
#
#          genre  theaters  runtime  ...                            title  year  \
# 1       Action    4662.0    181.0  ...        18 anni tra una settimana  1991
# 2    Adventure    4164.0    136.0  ...                 Ride a Wild Pony  1976
# 3       Action    4276.0    141.0  ...                            Diner  1982
# 4    Adventure    4134.0    136.0  ...  A che servono questi quattrini?  1942
# 5       Action    4474.0    156.0  ...           The Uranian Conspiracy  1978
# ..         ...       ...      ...  ...                              ...   ...
# 494  Adventure    3847.0     96.0  ...                  Kiss Me, Stupid  1964
# 495  Adventure    3933.0    115.0  ...                         Il bacio  1974
# 496     Action    3555.0     98.0  ...                    Killer's Kiss  1955
# 497    Western    2609.0    137.0  ...         Kiss of the Spider Woman  1985
# 499  Adventure    2922.0    114.0  ...                       Cat People  1982
#
#         genre  duration                 country  \
# 1       Drama        98                   Italy
# 2    Romantic        91           United States
# 3      Comedy        95           United States
# 4      Comedy        85                   Italy
# 5         Spy       117  Italy, Germany, Israel
# ..        ...       ...                     ...
# 494    Comedy       123           United States
# 495     Drama       105                   Italy
# 496      Noir        67           United States
# 497     Drama       119   United States, Brazil
# 499    Horror       118           United States
#
#                                 directors avg_vote critics_vote  public_vote  \
# 1                           Luigi Perelli      6.5         6.00          7.0
# 2                             Don Chaffey      5.6         6.00          5.0
# 3                          Barry Levinson      7.0         8.00          6.0
# 4                          Esodo Pratelli      5.9         5.33          7.0
# 5    Gianfranco Baldanello, Menahem Golan      4.8         3.50          6.0
# ..                                    ...      ...          ...          ...
# 494                          Billy Wilder      8.3         8.43          8.0
# 495                      Mario Lanfranchi      3.8         4.00          4.0
# 496                       Stanley Kubrick      7.1         7.10          7.0
# 497                        Hector Babenco      7.7         7.75          8.0
# 499                         Paul Schrader      6.7         6.79          7.0
#
#                                            description
# 1    Samantha, not yet eighteen, leaves the comfort...
# 2    In the Australia of the pioneers, a boy and a ...
# 3    Five boys from Baltimore have a habit of meeti...
# 4    With a stratagem, the penniless and somewhat p...
# 5    Two Israeli secret agents discover that traffi...
# ..                                                 ...
# 494  Orville is a piano teacher from a provincial t...
# 495  A coveted noble title (and relative patrimony)...
# 496  Dave Gordon, a failed boxer, meets Gloria who ...
# 497  Two men are being held in the same cell in a S...
# 499  Irena Gallier (Kinski) is already grown up, bu...
#
# [474 rows x 22 columns]

# %%
df_final.dtypes
# Out:
# release_date        object
# title               object
# production_cost    float64
# domestic_gross     float64
# worldwide_gross    float64
# opening_weekend    float64
# mpaa                object
# genre               object
# theaters           float64
# runtime            float64
# year               float64
# filmtv_id            int64
# title               object
# year                 int64
# genre               object
# duration             int64
# country             object
# directors           object
# avg_vote           float64
# critics_vote       float64
# public_vote        float64
# description         object
# dtype: object

# %%
columns = list(df_final.columns)

start1 = columns.index("production_cost")
end1 = columns.index("opening_weekend")
start2 = columns.index("theaters")
end2 = columns.index("year")

for index, col in enumerate(columns):
    if (start1 <= index) & (index <= end1):
        df_final[col] = df_final[col].astype(int)
    if (start2 <= index) & (index <= end2):
        df_final[col] = df_final[col].astype(int)
# Out:
# /var/folders/c9/6zwnylqn0v3b4prwfdpt2ndc0000gn/T/ipykernel_996/3464179896.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[col] = df_final[col].astype(int)
# /var/folders/c9/6zwnylqn0v3b4prwfdpt2ndc0000gn/T/ipykernel_996/3464179896.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[col] = df_final[col].astype(int)

# %%
df_final.dtypes
# Out:
# release_date        object
# title               object
# production_cost      int64
# domestic_gross       int64
# worldwide_gross      int64
# opening_weekend      int64
# mpaa                object
# genre               object
# theaters             int64
# runtime              int64
# year                 int64
# filmtv_id            int64
# title               object
# year                 int64
# genre               object
# duration             int64
# country             object
# directors           object
# avg_vote           float64
# critics_vote       float64
# public_vote        float64
# description         object
# dtype: object

# %%
df_final.head(2)
# Out:
#   release_date                                        title  production_cost  \
# 1   2019-04-23                            Avengers: Endgame        400000000
# 2   2011-05-20  Pirates of the Caribbean: On Stranger Tides        379000000
#
#    domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 1       858373000       2797800564        357115007  PG-13     Action
# 2       241071802       1045713802         90151958  PG-13  Adventure
#
#    theaters  runtime  ...                      title  year     genre  \
# 1      4662      181  ...  18 anni tra una settimana  1991     Drama
# 2      4164      136  ...           Ride a Wild Pony  1976  Romantic
#
#    duration        country      directors avg_vote critics_vote  public_vote  \
# 1        98          Italy  Luigi Perelli      6.5          6.0          7.0
# 2        91  United States    Don Chaffey      5.6          6.0          5.0
#
#                                          description
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
#
# [2 rows x 22 columns]

# %%
df_final[df_final["title"] == "The Incredibles"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/c9/6zwnylqn0v3b4prwfdpt2ndc0000gn/T/ipykernel_996/1095630921.py in <module>
# ----> 1 df_final[df_final["title"] == "The Incredibles"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3443         # Do we have a (boolean) DataFrame?
#    3444         if isinstance(key, DataFrame):
# -> 3445             return self.where(key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10734         try_cast=lib.no_default,
#   10735     ):
# > 10736         return super().where(cond, other, inplace, axis, level, errors, try_cast)
#   10737
#   10738     @deprecate_nonkeyword_arguments(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9030             )
#    9031
# -> 9032         return self._where(cond, other, inplace, axis, level, errors=errors)
#    9033
#    9034     @final
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors)
#    8792
#    8793         cond = -cond if inplace else cond
# -> 8794         cond = cond.reindex(self._info_axis, axis=self._info_axis_number, copy=False)
#    8795
#    8796         # try to align with other
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    4770         kwargs.pop("axis", None)
#    4771         kwargs.pop("labels", None)
# -> 4772         return super().reindex(**kwargs)
#    4773
#    4774     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4816
#    4817         # perform the reindex on the axes
# -> 4818         return self._reindex_axes(
#    4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4589         columns = axes["columns"]
#    4590         if columns is not None:
# -> 4591             frame = frame._reindex_columns(
#    4592                 columns, method, copy, level, fill_value, limit, tolerance
#    4593             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    4634             new_columns, method=method, level=level, limit=limit, tolerance=tolerance
#    4635         )
# -> 4636         return self._reindex_with_indexers(
#    4637             {1: [new_columns, indexer]},
#    4638             copy=copy,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881
#    4882             # TODO: speed up on homogeneous DataFrame objects
# -> 4883             new_data = new_data.reindex_indexer(
#    4884                 index,
#    4885                 indexer,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis
